# %% [markdown]
# ***MULTIVARIATE REGRESSION MODELS***

# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
aqf_data=pd.read_csv("/content/AirQualityUCI.csv")
print(aqf_data.head())
# Out:
#         Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  3/10/2004  18:00:00     2.6       1360.0     150.0      11.9
# 1  3/10/2004  19:00:00     2.0       1292.0     112.0       9.4
# 2  3/10/2004  20:00:00     2.2       1402.0      88.0       9.0
# 3  3/10/2004  21:00:00     2.2       1376.0      80.0       9.2
# 4  3/10/2004  22:00:00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH  Unnamed: 15  Unnamed: 16
# 0  13.6  48.9  0.7578          NaN          NaN
# 1  13.3  47.7  0.7255          NaN          NaN
# 2  11.9  54.0  0.7502          NaN          NaN
# 3  11.0  60.0  0.7867          NaN          NaN
# 4  11.2  59.6  0.7888          NaN          NaN

# %%
aqf_data.replace(-200,np.nan,inplace=True)
aqf_data.dropna(how='all',axis=0, inplace=True)
aqf_data.dropna(how='all',axis=1, inplace=True)
print(aqf_data.isnull().sum())
print(aqf_data.head())
# Out:
# Date                0
# Time                0
# CO(GT)           1683
# PT08.S1(CO)       366
# NMHC(GT)         8443
# C6H6(GT)          366
# PT08.S2(NMHC)     366
# NOx(GT)          1639
# PT08.S3(NOx)      366
# NO2(GT)          1642
# PT08.S4(NO2)      366
# PT08.S5(O3)       366
# T                 366
# RH                366
# AH                366
# dtype: int64
#         Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  3/10/2004  18:00:00     2.6       1360.0     150.0      11.9
# 1  3/10/2004  19:00:00     2.0       1292.0     112.0       9.4
# 2  3/10/2004  20:00:00     2.2       1402.0      88.0       9.0
# 3  3/10/2004  21:00:00     2.2       1376.0      80.0       9.2
# 4  3/10/2004  22:00:00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH
# 0  13.6  48.9  0.7578
# 1  13.3  47.7  0.7255
# 2  11.9  54.0  0.7502
# 3  11.0  60.0  0.7867
# 4  11.2  59.6  0.7888

# %%
x=aqf_data[["PT08.S1(CO)","PT08.S2(NMHC)","PT08.S3(NOx)","PT08.S5(O3)","T","RH","AH"]]
y=aqf_data[["CO(GT)"]]
print(x.head())
print(y.head())
# Out:
#    PT08.S1(CO)  PT08.S2(NMHC)  PT08.S3(NOx)  PT08.S5(O3)     T    RH      AH
# 0       1360.0         1046.0        1056.0       1268.0  13.6  48.9  0.7578
# 1       1292.0          955.0        1174.0        972.0  13.3  47.7  0.7255
# 2       1402.0          939.0        1140.0       1074.0  11.9  54.0  0.7502
# 3       1376.0          948.0        1092.0       1203.0  11.0  60.0  0.7867
# 4       1272.0          836.0        1205.0       1110.0  11.2  59.6  0.7888
#    CO(GT)
# 0     2.6
# 1     2.0
# 2     2.2
# 3     2.2
# 4     1.6

# %%
# Impute NaN values in x and y using their means
x.fillna(x.mean(), inplace=True)
y.fillna(y.mean(), inplace=True)
x.isnull().sum().sum()
y.isnull().sum().sum()
# Out:
# /tmp/ipykernel_928/1138348764.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x.fillna(x.mean(), inplace=True)
# /tmp/ipykernel_928/1138348764.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y.fillna(y.mean(), inplace=True)
# np.int64(0)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# ***REGRESSION BASELINES***

# %%
models={
        Ridge(),
        RandomForestRegressor(n_estimators=100,random_state=42),
        XGBRegressor(n_estimators=100,learning_rate=0.5,random_state=42)
}

# %%
x_train.fillna(x_train.mean(), inplace=True)
y_train.fillna(y_train.mean(), inplace=True)

x_test.fillna(x_train.mean(), inplace=True)
y_test.fillna(y_train.mean(), inplace=True)

for current_model in models:
  current_model.fit(x_train, y_train.values.ravel())
  pred=current_model.predict(x_test)
print(pred)

# %%
rmse=mean_squared_error(y_test,pred)
mae=mean_absolute_error(y_test,pred)
r2=r2_score(y_test,pred)
print("Root Mean Squared Error: ",rmse)
print("Mean Absolute Error: ",mae)
print("R2 Score: ",r2)
# Out:
# Root Mean Squared Error:  0.42741649024758216
# Mean Absolute Error:  0.4404433069282668
# R2 Score:  0.7697808388610299

# %%
import joblib
from xgboost import XGBRegressor
xgboost_model = None
for ml_model in models:
    if isinstance(ml_model, XGBRegressor):
        xgboost_model = ml_model
        break
if xgboost_model is not None:
    joblib.dump(xgboost_model, 'xgboost_aqi_model.pkl')
    print("Successfully found and saved your trained XGBoost model!")
else:
    print(" Could not find an XGBoost model in your models set.")
# Out:
# Successfully found and saved your trained XGBoost model!

# %% [markdown]
# ***DEEP LEARNING MODEL***

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D,MaxPooling1D,LSTM,Bidirectional,Dense,Dropout
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
feature_cols = ["PT08.S1(CO)", "PT08.S2(NMHC)", "PT08.S3(NOx)", "PT08.S5(O3)", "T", "RH", "AH"]
target_col = "CO(GT)"

# %%
print(x.values)
print(y.values)
# Out:
# [[1.360e+03 1.046e+03 1.056e+03 ... 1.360e+01 4.890e+01 7.578e-01]
#  [1.292e+03 9.550e+02 1.174e+03 ... 1.330e+01 4.770e+01 7.255e-01]
#  [1.402e+03 9.390e+02 1.140e+03 ... 1.190e+01 5.400e+01 7.502e-01]
#  ...
#  [1.142e+03 1.063e+03 6.030e+02 ... 2.690e+01 1.830e+01 6.406e-01]
#  [1.003e+03 9.610e+02 7.020e+02 ... 2.830e+01 1.350e+01 5.139e-01]
#  [1.071e+03 1.047e+03 6.540e+02 ... 2.850e+01 1.310e+01 5.028e-01]]
# [[2.6]
#  [2. ]
#  [2.2]
#  ...
#  [2.4]
#  [2.1]
#  [2.2]]

# %%
Scaler_X=MinMaxScaler()
Scaler_Y=MinMaxScaler()
X_scaled = Scaler_X.fit_transform(x_train)
joblib.dump(Scaler_X, 'scaler_X.pkl')
Y_scaled=Scaler_Y.fit_transform(y_train.values.reshape(-1, 1))
print(X_scaled)
print(Y_scaled)
# Out:
# [[0.32507765 0.30374297 0.21748988 ... 0.43479202 0.50357485 0.41090274]
#  [0.2275664  0.16876024 0.36171114 ... 0.2688172  0.61006289 0.26951082]
#  [0.18521177 0.14472966 0.2901313  ... 0.18709677 0.4        0.10873283]
#  ...
#  [0.56927495 0.56198798 0.07285049 ... 0.52688172 0.65660377 0.72315887]
#  [0.55348169 0.49098853 0.15205421 ... 0.45376344 0.33333333 0.2921859 ]
#  [0.56353195 0.44347351 0.07920373 ... 0.32688172 0.59119497 0.32746909]]
# [[0.27966102]
#  [0.09322034]
#  [0.09322034]
#  ...
#  [0.29661017]
#  [0.33050847]
#  [0.31355932]]

# %%
lookback=24
x_sequences=[]
y_targets=[]
for i in range(lookback,len(X_scaled)):
  x_sequences.append(X_scaled[i-lookback:i])
x_sequences=np.array(x_sequences)
y_targets=np.array(Y_scaled[lookback:])
print(x_sequences)
print(y_targets)
# Out:
# [[[0.32507765 0.30374297 0.21748988 ... 0.43479202 0.50357485 0.41090274]
#   [0.2275664  0.16876024 0.36171114 ... 0.2688172  0.61006289 0.26951082]
#   [0.18521177 0.14472966 0.2901313  ... 0.18709677 0.4        0.10873283]
#   ...
#   [0.26920316 0.28181322 0.22193986 ... 0.54408602 0.42767296 0.51033573]
#   [0.23689878 0.24959039 0.21389242 ... 0.6688172  0.25031447 0.47593217]
#   [0.22325915 0.11906062 0.26471834 ... 0.32043011 0.65408805 0.35468895]]
#
#  [[0.2275664  0.16876024 0.36171114 ... 0.2688172  0.61006289 0.26951082]
#   [0.18521177 0.14472966 0.2901313  ... 0.18709677 0.4        0.10873283]
#   [0.31371141 0.44620426 0.15417196 ... 0.63870968 0.21886792 0.38611152]
#   ...
#   [0.23689878 0.24959039 0.21389242 ... 0.6688172  0.25031447 0.47593217]
#   [0.22325915 0.11906062 0.26471834 ... 0.32043011 0.65408805 0.35468895]
#   [0.25125628 0.24030584 0.20415078 ... 0.43010753 0.74591195 0.59717539]]
#
#  [[0.18521177 0.14472966 0.2901313  ... 0.18709677 0.4        0.10873283]
#   [0.31371141 0.44620426 0.15417196 ... 0.63870968 0.21886792 0.38611152]
#   [0.09475951 0.01037684 0.56882677 ... 0.10107527 0.54591195 0.10384597]
#   ...
#   [0.22325915 0.11906062 0.26471834 ... 0.32043011 0.65408805 0.35468895]
#   [0.25125628 0.24030584 0.20415078 ... 0.43010753 0.74591195 0.59717539]
#   [0.68772434 0.56417258 0.04828463 ... 0.15483871 0.85786164 0.2495724 ]]
#
#  ...
#
#  [[0.1758794  0.19442927 0.27191868 ... 0.47526882 0.52201258 0.48854029]
#   [0.1672649  0.22719825 0.32825074 ... 0.49677419 0.48301887 0.4863412 ]
#   [0.6022972  0.64827963 0.05633206 ... 0.22580645 0.2591195  0.07315643]
#   ...
#   [0.73869347 0.64718733 0.05167302 ... 0.37634409 0.70062893 0.46664712]
#   [0.6338837  0.56908793 0.05717916 ... 0.61290323 0.45660377 0.669892  ]
#   [0.07178751 0.08738394 0.40406607 ... 0.35483871 0.60880503 0.37482285]]
#
#  [[0.1672649  0.22719825 0.32825074 ... 0.49677419 0.48301887 0.4863412 ]
#   [0.6022972  0.64827963 0.05633206 ... 0.22580645 0.2591195  0.07315643]
#   [0.39913855 0.43801202 0.13850064 ... 0.53333333 0.49685535 0.56536187]
#   ...
#   [0.6338837  0.56908793 0.05717916 ... 0.61290323 0.45660377 0.669892  ]
#   [0.07178751 0.08738394 0.40406607 ... 0.35483871 0.60880503 0.37482285]
#   [0.56927495 0.56198798 0.07285049 ... 0.52688172 0.65660377 0.72315887]]
#
#  [[0.6022972  0.64827963 0.05633206 ... 0.22580645 0.2591195  0.07315643]
#   [0.39913855 0.43801202 0.13850064 ... 0.53333333 0.49685535 0.56536187]
#   [0.12275664 0.04915347 0.39601864 ... 0.33548387 0.49811321 0.28143478]
#   ...
#   [0.07178751 0.08738394 0.40406607 ... 0.35483871 0.60880503 0.37482285]
#   [0.56927495 0.56198798 0.07285049 ... 0.52688172 0.65660377 0.72315887]
#   [0.55348169 0.49098853 0.15205421 ... 0.45376344 0.33333333 0.2921859 ]]]
# [[0.17396183]
#  [0.40677966]
#  [0.08474576]
#  ...
#  [0.29661017]
#  [0.33050847]
#  [0.31355932]]

# %%
split_idx=int(0.8*len(x_sequences))
X_train,X_test=x_sequences[:split_idx],x_sequences[split_idx:]
Y_train,Y_test=y_targets[:split_idx],y_targets[split_idx:]
print(X_train.shape)
print(X_test.shape)
# Out:
# (5968, 24, 7)
# (1493, 24, 7)

# %%
print("NaN values in X_train:", np.isnan(X_train).sum())
print("NaN values in Y_train:", np.isnan(Y_train).sum())
# Out:
# NaN values in X_train: 0
# NaN values in Y_train: 0

# %%
keras_model=Sequential([
    Conv1D(filters=32,kernel_size=3,activation='relu',input_shape=(lookback,x.shape[1])),
    MaxPooling1D(pool_size=2),
    Dropout(0.2),
    Bidirectional(LSTM(50,activation="tanh",return_sequences=False)),
    Dropout(0.2),
    Dense(32,activation='relu'),
    Dense(1)
])
keras_model.compile(optimizer='adam', loss='huber', metrics=['mae'])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
keras_model.fit(X_train,Y_train,epochs=20,batch_size=32,validation_split=0.1,verbose=1)
# Out:
# Epoch 1/20
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - loss: 0.0068 - mae: 0.0849 - val_loss: 0.0058 - val_mae: 0.0758
# Epoch 2/20
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0064 - mae: 0.0812 - val_loss: 0.0058 - val_mae: 0.0764
# Epoch 3/20
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0065 - mae: 0.0819 - val_loss: 0.0058 - val_mae: 0.0751
# Epoch 4/20
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0064 - mae: 0.0807 - val_loss: 0.0058 - val_mae: 0.0760
# Epoch 5/20
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0064 - mae: 0.0806 - val_loss: 0.0058 - val_mae: 0.0766
# Epoch 6/20
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0063 - mae: 0.0798 - val_loss: 0.0058 - val_mae: 0.0780
# Epoch 7/20
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0063 - mae: 0.0798 - val_loss: 0.0058 - val_mae: 0.0753
# Epoch 8/20
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0063 - mae: 0.0796 - val_loss: 0.0058 - val_mae: 0.0768
# Epoch 9/20
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0063 - mae: 0.0799 - val_loss: 0.0058 - val_mae: 0.0753
# Epoch 10/20
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0063 - mae: 0.0795 - val_loss: 0.0058 - val_mae: 0.0758
# Epoch 11/20
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0063 - mae: 0.0792 - val_loss: 0.0058 - val_mae: 0.0758
# Epoch 12/20
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.0063 - mae: 0.0794 - val_loss: 0.0058 - val_mae: 0.0779
# Epoch 13/20
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0063 - mae: 0.0796 - val_loss: 0.0062 - val_mae: 0.0847
# Epoch 14/20
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0063 - mae: 0.0794 - val_loss: 0.0058 - val_mae: 0.0752
# Epoch 15/20
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0062 - mae: 0.0791 - val_loss: 0.0058 - val_mae: 0.0751
# Epoch 16/20
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.0062 - mae: 0.0792 - val_loss: 0.0058 - val_mae: 0.0756
# Epoch 17/20
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0062 - mae: 0.0797 - val_loss: 0.0058 - val_mae: 0.0776
# Epoch 18/20
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0062 - mae: 0.0791 - val_loss: 0.0058 - val_mae: 0.0783
# Epoch 19/20
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0062 - mae: 0.0794 - val_loss: 0.0058 - val_mae: 0.0755
# Epoch 20/20
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0062 - mae: 0.0794 - val_loss: 0.0058 - val_mae: 0.0765

# %%
predictions=keras_model.predict(X_test)
predictions_actual=Scaler_Y.inverse_transform(predictions)
Y_test_actual=Scaler_Y.inverse_transform(Y_test)
print(predictions_actual)
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# [[2.2591043]
#  [2.1535041]
#  [2.1212983]
#  ...
#  [2.3113337]
#  [2.3809426]
#  [2.350868 ]]

# %%
rmse = (mean_squared_error(Y_test_actual, predictions_actual))** 2
mae = mean_absolute_error(Y_test_actual,predictions_actual)
print("Root Mean Squared Error:", rmse)
print("Mean Absolute Error:", mae)
# Out:
# Root Mean Squared Error: 2.6341007510718213
# Mean Absolute Error: 0.917220913079535

# %%
plt.figure(figsize=(12, 6))
plt.plot(Y_test_actual[:150], label='Actual CO(GT)', color='black', alpha=0.7)
plt.plot(predictions_actual[:150], label='CNN-BiLSTM Predicted CO(GT)', color='red')
plt.title('Air Quality Forecasting Comparison (First 150 Hours of Test Set)')
plt.xlabel('Time Steps (Hours)')
plt.ylabel('CO Concentration (mg/m³)')
plt.legend()
plt.show()

# %%
import os
import joblib
from xgboost import XGBRegressor

print(" Inspecting your Colab files...")
if 'models' in globals():
    print(" Found 'models' variable in your session!")
    xgboost_model = None
    for ml_model_iter in globals()['models']:
        if isinstance(ml_model_iter, XGBRegressor):
            xgboost_model = ml_model_iter
            break

    if xgboost_model is not None:
        joblib.dump(xgboost_model, '/content/xgboost_aqi_model.pkl')
        print(" Saved your actual trained XGBoost model to /content/xgboost_aqi_model.pkl")
    else:
         print(" Found 'models', but no XGBRegressor inside it. Saving a fallback model...")
         from xgboost import XGBRegressor
         import numpy as np
         fallback = XGBRegressor(n_estimators=100, learning_rate=0.5, random_state=42)
         fallback.fit(np.random.rand(10, 7), np.random.rand(10, 1))
         joblib.dump(fallback, '/content/xgboost_aqi_model.pkl')
else:
    print(" 'models' variable NOT found. Did you run your training cell in this session?")
    print(" Generating and saving a fallback model so your Streamlit app can open...")
    from xgboost import XGBRegressor
    import numpy as np
    fallback = XGBRegressor(n_estimators=100, learning_rate=0.5, random_state=42)
    fallback.fit(np.random.rand(10, 7), np.random.rand(10, 1))
    joblib.dump(fallback, '/content/xgboost_aqi_model.pkl')

if not os.path.exists('/content/scaler_X.pkl') or not os.path.exists('/content/scaler_y.pkl'):
    print(" Creating placeholder scalers...")
    from sklearn.preprocessing import MinMaxScaler
    import numpy as np
    scaler_X = MinMaxScaler().fit(np.random.rand(10, 7))
    scaler_y = MinMaxScaler().fit(np.random.rand(10, 1))
    joblib.dump(scaler_X, '/content/scaler_X.pkl')
    joblib.dump(scaler_y, '/content/scaler_y.pkl')

print("\n Active Files in your Main Directory:")
print(os.listdir('/content'))
# Out:
#  Inspecting your Colab files...
#  Found 'models' variable in your session!
#  Saved your actual trained XGBoost model to /content/xgboost_aqi_model.pkl
#
#  Active Files in your Main Directory:
# ['.config', 'scaler_y.pkl', 'xgboost_aqi_model.pkl', 'AirQualityUCI.csv', 'scaler_X.pkl', 'sample_data']

# %%
import joblib
joblib.dump(Scaler_X, '/content/scaler_X.pkl')
joblib.dump(Scaler_Y, '/content/scaler_y.pkl')
joblib.dump(xgboost_model, '/content/xgboost_aqi_model.pkl')

print("Real scalers and model saved successfully!")
# Out:
# Real scalers and model saved successfully!

# %%
keras_model.save('cnn_bilstm_model.keras')
